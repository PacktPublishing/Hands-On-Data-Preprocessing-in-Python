# %% [markdown]
# ## Hands-On Data Preprocessing in Python
# Learn how to effectively prepare data for successful data analytics
#
#     AUTHOR: Dr. Roy Jafari
#
# ### Chapter 9: Data Cleaning - Levels Ⅰ and Ⅱ
# #### Excercises

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Excercise 1
# In your own words describe the relationship between analytics goals and data cleaning. Your response should answer the following questions.
#
#     a.	 Is data cleaning a separate step of data analytics and can be done in isolation? In other words, can data cleaning be performed without knowing about the analytics?
#     b.	If the answer to the previous question is no, are there any types of data cleaning that can be done in isolation?
#     c.	What is the role of analytic tools in the relationship between analytic goals and data cleaning?

# %% [markdown]
# # Excercise 2
#
# A local airport to analyze the usage of its parking has employed a Single Beam Infrared Detector (SBID) technology to count the number of people who pass the gate from the parking to the airport.
# As shown in the following figure, an SBDI records the time every time the infrared connection is blocked signaling the entrance or the exit of a passenger.

# %% [markdown]
# Figure 9.22 An example of Single Beam Infrared Detector (SBID) is shown below

# %%
import matplotlib.image as mpimg
plt.figure(figsize=(12,12))
plt.imshow(mpimg.imread('People Counter.jpg'))
plt.show()

# %% [markdown]
# Unfortunately, the person who installed the SBID was not current with the latest and greatest database technology so they have set up the system in a way that the recoded date of each day is stored in an excel file. The excel files are named after the day that the records come from. You have been hired to help and analyze the data. Your manager has given you access to the zipped file SBID_Data.zip. The zipped file contains fourteen files each keeping the data of one day between OCT 12, 2020 to OCT 25, 2020. Your manager has informed you that due to security reasons she cannot share all the nearly 3000  files with you. She has tasked you with the following for the 14 files she has shared with you.
#
#     a.	 Write a code that can automatically consolidate all the files into one Pandas DataFrame.
#     b.	Come up with the bar chart that shows the average airport passenger traffic per hour.
#     c.	Label and describe the data cleaning steps you did in this exercise.

# %% [markdown]
# a.

# %% [markdown]
# b.

# %% [markdown]
# c.
